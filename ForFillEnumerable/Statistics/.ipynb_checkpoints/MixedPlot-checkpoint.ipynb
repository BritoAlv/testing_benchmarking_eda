# %% [markdown]
# # To Create A Plot With More than One DataFrame.

# %%
library(dplyr)
library(tidyverse)
library(repr)
options(repr.plot.width = 9, repr.plot.height = 5 ,repr.plot.res = 300)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0     ✔ purrr   1.0.1
# ✔ tibble  3.1.8     ✔ stringr 1.5.0
# ✔ tidyr   1.2.0     ✔ forcats 0.5.2
# ✔ readr   2.1.3
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# it's almost the same process it's just we need to mix the data:

#load data

generate_data <- function(...) {
    values <- list(...)
    values <- map(values, ~ read.csv(file = .x))
    return(bind_rows(values))
}

mixed_data <- generate_data("./Enumerable.csv","./For.csv", "./Fill.csv", "./BufferCopy.csv", "./Copy.csv", "./CopyX2.csv")
mixed_data
# Out:
#    X Algoritmo       input_size Tiempo     cte_tiempo Memoria cte_memoria
# 1  1 Fill              1000        67.4187 0.06741870 0       0
# 2  2 Fill             10000      1055.1358 0.10551000 0       0
# 3  3 Fill             20000      2117.5100 0.10587500 0       0
# 4  4 Fill             30000      3197.2204 0.10657333 0       0
# 5  5 Fill            100000     13061.8367 0.13061800 0       0
# 6  6 Fill            200000     27382.1693 0.13691100 0       0
# 7  7 Fill            300000     41082.9130 0.13694300 0       0
# 8  8 Fill            400000     58078.6604 0.14519675 0       0
# 9  9 Fill            500000     73258.0209 0.14651600 0       0
# 10 1 BufferCopy        1000       167.6624 0.16766240 0       0
# 11 2 BufferCopy       10000       850.7533 0.08507533 0       0
# 12 3 BufferCopy       20000      1927.8498 0.09639000 0       0
# 13 4 BufferCopy       30000      2888.4957 0.09628333 0       0
# 14 5 BufferCopy      100000     11238.2024 0.11238200 0       0
# 15 6 BufferCopy      200000     24943.2837 0.12471650 0       0
# 16 7 BufferCopy      300000     40415.6605 0.13471900 0       0
# 17 8 BufferCopy      400000     55836.1041 0.13959025 0       0
# 18 9 BufferCopy      500000     71758.6866 0.14351740 0       0
# 19 1 CopyConsecutive   1000       372.9050 0.37290500 0       0
# 20 2 CopyConsecutive  10000      1341.3707 0.13414000 0       0
# 21 3 CopyConsecutive  20000      2573.6767 0.12868500 0       0
# 22 4 CopyConsecutive  30000      3714.8694 0.12383000 0       0
# 23 5 CopyConsecutive 100000     15243.0720 0.15243100 0       0
# 24 6 CopyConsecutive 200000     31545.6211 0.15772799 0       0
# 25 7 CopyConsecutive 300000     47388.2834 0.15796100 0       0
# 26 8 CopyConsecutive 400000     63199.7153 0.15799925 0       0
# 27 9 CopyConsecutive 500000     81072.8425 0.16214560 0       0
# 28 1 CopyX2            1000       116.2531 0.11625310 0       0
# 29 2 CopyX2           10000       764.5751 0.07645751 0       0
# 30 3 CopyX2           20000      1807.8768 0.09039500 0       0
# 31 4 CopyX2           30000      2857.3660 0.09524667 0       0
# 32 5 CopyX2          100000     10497.0934 0.10497093 0       0
# 33 6 CopyX2          200000     25353.1770 0.12676600 0       0
# 34 7 CopyX2          300000     40224.3127 0.13408100 0       0
# 35 8 CopyX2          400000     55769.6332 0.13942400 0       0
# 36 9 CopyX2          500000     70917.6400 0.14183520 0       0

# %%
x = mixed_data$input_size
mixedplot <- ggplot(
  data = mixed_data, mapping = aes(x = x, y = Tiempo, colour = Algoritmo)) +
  geom_point(size = 2) +
  labs(x = "Tamaño De Entrada", y = "Tiempo Consumido") +
  geom_line() +
  scale_x_continuous(breaks = x, labels = x) +
  theme(axis.text.x = element_text(angle = 90))

mixedplot
# Out:
# plot without title
